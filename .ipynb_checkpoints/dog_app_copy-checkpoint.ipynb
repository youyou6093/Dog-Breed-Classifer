# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the Jupyter Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Write your Algorithm
# * [Step 6](#step6): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# Make sure that you've downloaded the required human and dog datasets:
#
# **Note: if you are using the Udacity workspace, you *DO NOT* need to re-download these - they can be found in the `/data` folder as noted in the cell below.**
#
# * Download the [dog dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip).  Unzip the folder and place it in this project's home directory, at the location `/dog_images`.
#
# * Download the [human dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/lfw.zip).  Unzip the folder and place it in the home directory, at location `/lfw`.
#
# *Note: If you are using a Windows machine, you are encouraged to use [7zip](http://www.7-zip.org/) to extract the folder.*
#
# In the code cell below, we save the file paths for both the human (LFW) dataset and dog dataset in the numpy arrays `human_files` and `dog_files`.

# %%
import numpy as np
from glob import glob

# load filenames for human and dog images
human_files = np.array(glob("lfw/*/*"))
dog_files = np.array(glob("dog_images/*/*/*"))

# print number of images in each dataset
print('There are %d total human images.' % len(human_files))
print('There are %d total dog images.' % len(dog_files))
# Out:
# There are 13233 total human images.
# There are 8350 total dog images.

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# In this section, we use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.
#
# OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.  In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[0])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.

# %% [markdown]
# __Answer:__
#
# 96% of the first 100 images in human_files have a detected human face
#
# 18% of the first 100 images in dog_files have a detected human face

# %%
from tqdm import tqdm

human_files_short = human_files[:100]
dog_files_short = dog_files[:100]

#-#-# Do NOT modify the code above this line. #-#-#

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
human_files_performance = (sum(face_detector(i) for i in human_files_short)) / len(human_files_short)
dog_files_performance = (sum(face_detector(i) for i in dog_files_short)) / len(dog_files_short)
print ("detected face percentage on human : {}".format(human_files_performance))
print ("detected face percentage on dog : {}".format(dog_files_performance))
# Out:
# detected face percentage on human : 0.96
# detected face percentage on dog : 0.18

# %% [markdown]
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Test performance of anotherface detection algorithm.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a [pre-trained model](http://pytorch.org/docs/master/torchvision/models.html) to detect dogs in images.
#
# ### Obtain Pre-trained VGG-16 Model
#
# The code cell below downloads the VGG-16 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
import torch
import torchvision.models as models

# define VGG16 model
VGG16 = models.vgg16(pretrained=True)

# check if CUDA is available
use_cuda = torch.cuda.is_available()

# move model to GPU if CUDA is available
if use_cuda:
    VGG16 = VGG16.cuda()

# %% [markdown]
# Given an image, this pre-trained VGG-16 model returns a prediction (derived from the 1000 possible categories in ImageNet) for the object that is contained in the image.

# %% [markdown]
# ### (IMPLEMENTATION) Making Predictions with a Pre-trained Model
#
# In the next code cell, you will write a function that accepts a path to an image (such as `'dogImages/train/001.Affenpinscher/Affenpinscher_00001.jpg'`) as input and returns the index corresponding to the ImageNet class that is predicted by the pre-trained VGG-16 model.  The output should always be an integer between 0 and 999, inclusive.
#
# Before writing the function, make sure that you take the time to learn  how to appropriately pre-process tensors for pre-trained models in the [PyTorch documentation](http://pytorch.org/docs/stable/torchvision/models.html).

# %%
from PIL import Image
from PIL import ImageFile
import PIL
import torchvision.transforms as transforms
# ImageFile.LOAD_TRUNCATED_IMAGES = True
# print(PIL.__version__)

device = 'cpu'
if use_cuda is True:
    device = 'cuda'
print (device)

def VGG16_predict(img_path):
    '''
    Use pre-trained VGG-16 model to obtain index corresponding to 
    predicted ImageNet class for image at specified path
    
    Args:
        img_path: path to an image
        
    Returns:
        Index corresponding to VGG-16 model's prediction
    '''
    
    ## TODO: Complete the function.
    ## Load and pre-process an image from the given img_path
    ## Return the *index* of the predicted class for that image
    image = Image.open(img_path)
    img_tensor = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor()
    ])(image)
    c, h, w = img_tensor.shape
    img_tensor = img_tensor.view(-1, c, h, w).to(device)
    return VGG16(img_tensor).cpu().detach().numpy().argmax()
# Out:
# cuda

# %% [markdown]
# ### (IMPLEMENTATION) Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained VGG-16 model, we need only check if the pre-trained model predicts an index between 151 and 268 (inclusive).
#
# Use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    ## TODO: Complete the function.
    ret = VGG16_predict(img_path)
    return True if ((ret >= 151) and (ret <= 268)) else False

# %%
test = Image.open(dog_files[2])

# %%
test
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x380 at 0x1C8620D0438>

# %%
import os
from os import listdir
from os.path import isfile, join
test = [x[0] for x in os.walk("dog_Images/train")]   
nums = []
for i in range(1, len(test)):
    onlyfiles = [f for f in listdir(test[i])]
#     print(len(onlyfiles))
    nums.append(len(onlyfiles))

# %%
plt.bar([i for i in range(133)], nums)
plt.xlabel('breed label')
plt.ylabel('num of training data')
# Out:
# Text(0, 0.5, 'num of training data')

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 2:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?

# %% [markdown]
# __Answer:__
#
# 0% of the images in human_files_short have a detected dog
#
# 91% of the iamges in dog_files_short have a detected dog

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
human_files_performance = (sum(dog_detector(i) for i in human_files_short)) / len(human_files_short)
dog_files_performance = (sum(dog_detector(i) for i in dog_files_short)) / len(dog_files_short)
print ("detected dog percentage on human : {}".format(human_files_performance))
print ("detected dog percentage on dog : {}".format(dog_files_performance))
# Out:
# detected dog percentage on human : 0.0
# detected dog percentage on dog : 0.91

# %% [markdown]
# We suggest VGG-16 as a potential network to detect dog images in your algorithm, but you are free to explore other pre-trained networks (such as [Inception-v3](http://pytorch.org/docs/master/torchvision/models.html#inception-v3), [ResNet-50](http://pytorch.org/docs/master/torchvision/models.html#id3), etc).  Please use the code cell below to test other pre-trained PyTorch models.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Report the performance of another pre-trained network.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 10%.  In Step 4 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have trouble distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dog_images/train`, `dog_images/valid`, and `dog_images/test`, respectively).  You may find [this documentation on custom datasets](http://pytorch.org/docs/stable/torchvision/datasets.html) to be a useful resource.  If you are interested in augmenting your training and/or validation data, check out the wide variety of [transforms](http://pytorch.org/docs/stable/torchvision/transforms.html?highlight=transform)!

# %%
import os
from torchvision import datasets
from PIL import ImageFile
# ImageFile.LOAD_TRUNCATED_IMAGES = True

### TODO: Write data loaders for training, validation, and test sets
## Specify appropriate transforms, and batch_sizes
def get_dataloader(batch_size, image_size, cropsize):


    transform = {
        'train': transforms.Compose([
            transforms.Resize((image_size, image_size)),
            transforms.RandomCrop(cropsize),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            )]
        ),
        'test': transforms.Compose([
            transforms.Resize((cropsize, cropsize)),
            transforms.ToTensor(),
            transforms.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            )]
        )
    }

    


    train_dataset = datasets.ImageFolder(
        root='dog_images/train',
        transform=transform['train']
    )
    valid_dataset = datasets.ImageFolder(
        root='dog_images/valid',
        transform=transform['test']
    )
    test_dataset = datasets.ImageFolder(
        root='dog_images/test',
        transform=transform['test']
    )

    train_dataset_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, num_workers=4
    )
    valid_dateset_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, shuffle=True, num_workers=4
    )
    test_dataset_loader = torch.utils.data.DataLoader(
        test_dataset, batch_size=batch_size, shuffle=True, num_workers=4
    )

    loaders_scratch = {
        'train': train_dataset_loader,
        'valid': valid_dateset_loader,
        'test': test_dataset_loader
    }

    return loaders_scratch

batch_size = 64
loaders_scratch = get_dataloader(batch_size, 80, 64)

# %% [markdown]
# **Question 3:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# **Answer**:
#
# - For the training images, my code will first resize the image to h, w = 80, 80 and then use the random crop to adjust it to 64 * 64 which is the input size for my neural network; for the test images, my code directly resizes the image to 64 * 64. The reason for such size is 64 is enough to encode different dog classes which won't be too large to cause the inefficiency in training.
#
# - I used random crop and random horizontal flip to augment the dataset.

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  Use the template in the code cell below.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    ### TODO: choose an architecture, and complete the class
    def __init__(self):
        super(Net, self).__init__()
        ## Define layers of a CNN
        self.conv0 = nn.Conv2d(3, 3, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv1 = nn.Conv2d(3, 6, kernel_size=5, stride=1, padding=1)
        self.conv2 = nn.Conv2d(6, 12, kernel_size=5, stride=2, padding=1)
        self.conv3 = nn.Conv2d(12, 24, kernel_size=3, stride=2, padding=1)
        self.fc1 = nn.Linear(24 * 7 * 7, 200)
        self.fc2 = nn.Linear(200, 500)  #output layer
        self.fc3 = nn.Linear(500, 133)
        self.drop = nn.Dropout(0.3)
    
    def forward(self, x):
        ## Define forward behavior
        # print (x.shape)
        x = x.view(-1, 3, 64, 64)
        x = self.pool(F.relu(self.conv0(x)))
        # print(x.shape, "expect -1, 3, 32, 32")
        x = F.relu(self.conv1(x))
        # print(x.shape, "expect -1, 6, 30, 30")   
        x = F.relu(self.conv2(x))
        # print(x.shape, "expect -1, 12, 14, 14")    
        x = F.relu(self.conv3(x))
        # print(x.shape, "expect -1, 24, 7, 7")   
        fc_input_dim = x.size(1) * x.size(2) * x.size(3)
        x = x.view(-1, fc_input_dim)
        x = F.relu(self.fc1(x))
        x = self.drop(x)
        x = F.relu(self.fc2(x))
        x = self.drop(x)
        x = self.fc3(x)
        return x

#-#-# You so NOT have to modify the code below this line. #-#-#

# instantiate the CNN
model_scratch = Net()

# move tensors to GPU if CUDA is available
if use_cuda:
    model_scratch.cuda()

# %% [markdown]
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# __Answer:__
#
# - The input size for my CNN is (3, 64, 64). The first step is to use convolutional layers to reduce the image size while also increasing the number of channels. Here I use four convolution layers conv0-3 to transform the input into (24, 7, 7). Reason: Use convolution to find the correlation within images at different locations.
#
# - Now I get the flatten input of  24 * 7 * 7. And start to construct the fully connected layer. Here I have three fully connected layers fc1-3. And fc3 is the output layer that has 133 classes. Reason: Use fully connected layers to achieve the final classification.
# - I also applied dropout in fully connected layers to prevent overfitting. Reason: prevent overfitting.

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/stable/optim.html).  Save the chosen loss function as `criterion_scratch`, and the optimizer as `optimizer_scratch` below.

# %%
import torch.optim as optim

### TODO: select loss function
criterion_scratch = nn.CrossEntropyLoss()

### TODO: select optimizer
# optimizer_scratch = optim.SGD(model_scratch.parameters(), lr=0.001, momentum=0.9)
optimizer_scratch = optim.Adam(model_scratch.parameters(), lr=0.001)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_scratch.pt'`.

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
    print (use_cuda)
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            optimizer.zero_grad()
            outputs = model(data)
            loss = criterion(outputs, target)
            loss.backward()
            optimizer.step()
            
            ## record the average training loss, using something like
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            # if batch_idx % 20 == 0:
            #     print (train_loss)
            
        ######################    
        # validate the model #
        ######################
        model.eval()
        for batch_idx, (data, target) in enumerate(loaders['valid']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## update the average validation loss
            outputs = model(data)
            loss = criterion(outputs, target)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))


        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss
            ))
        
        ## TODO: save the model if validation loss has decreased
        if valid_loss < valid_loss_min:
            valid_loss_min = valid_loss
            torch.save(model.state_dict(), save_path)
        
        
    # return trained model
    return model


# train the model
model_scratch = train(100, loaders_scratch, model_scratch, optimizer_scratch, 
                      criterion_scratch, use_cuda, 'model_scratch.pt')

# load the model that got the best validation accuracy
model_scratch.load_state_dict(torch.load('model_scratch.pt'))
# Out:
# True
# Epoch: 1 	Training Loss: 4.838947 	Validation Loss: 4.719857
# Epoch: 2 	Training Loss: 4.679485 	Validation Loss: 4.642764
# Epoch: 3 	Training Loss: 4.599528 	Validation Loss: 4.542905
# Epoch: 4 	Training Loss: 4.544975 	Validation Loss: 4.548060
# Epoch: 5 	Training Loss: 4.464468 	Validation Loss: 4.430639
# Epoch: 6 	Training Loss: 4.371269 	Validation Loss: 4.347827
# Epoch: 7 	Training Loss: 4.293505 	Validation Loss: 4.323296
# Epoch: 8 	Training Loss: 4.244960 	Validation Loss: 4.397836
# Epoch: 9 	Training Loss: 4.188478 	Validation Loss: 4.313042
# Epoch: 10 	Training Loss: 4.143707 	Validation Loss: 4.219260
# Epoch: 11 	Training Loss: 4.112051 	Validation Loss: 4.219919
# Epoch: 12 	Training Loss: 4.066308 	Validation Loss: 4.212342
# Epoch: 13 	Training Loss: 4.017780 	Validation Loss: 4.124779
# Epoch: 14 	Training Loss: 3.998571 	Validation Loss: 4.191406
# Epoch: 15 	Training Loss: 3.956622 	Validation Loss: 4.126843
# Epoch: 16 	Training Loss: 3.915026 	Validation Loss: 4.057922
# Epoch: 17 	Training Loss: 3.899005 	Validation Loss: 4.008240
# Epoch: 18 	Training Loss: 3.842116 	Validation Loss: 4.004308
# Epoch: 19 	Training Loss: 3.840656 	Validation Loss: 4.028394
# Epoch: 20 	Training Loss: 3.813911 	Validation Loss: 3.967511
# Epoch: 21 	Training Loss: 3.813446 	Validation Loss: 3.971646
# Epoch: 22 	Training Loss: 3.790324 	Validation Loss: 4.020500
# Epoch: 23 	Training Loss: 3.764256 	Validation Loss: 4.074783
# Epoch: 24 	Training Loss: 3.754350 	Validation Loss: 4.007272
# Epoch: 25 	Training Loss: 3.707929 	Validation Loss: 3.977589
# Epoch: 26 	Training Loss: 3.677197 	Validation Loss: 3.978709
# Epoch: 27 	Training Loss: 3.673521 	Validation Loss: 3.928490
# Epoch: 28 	Training Loss: 3.647408 	Validation Loss: 3.947167
# Epoch: 29 	Training Loss: 3.606624 	Validation Loss: 3.960861
# Epoch: 30 	Training Loss: 3.607522 	Validation Loss: 3.978152
# Epoch: 31 	Training Loss: 3.576376 	Validation Loss: 4.008832
# Epoch: 32 	Training Loss: 3.567481 	Validation Loss: 3.945903
# Epoch: 33 	Training Loss: 3.545549 	Validation Loss: 3.955530
# Epoch: 34 	Training Loss: 3.540877 	Validation Loss: 3.951215
# Epoch: 35 	Training Loss: 3.502413 	Validation Loss: 3.918913
# Epoch: 36 	Training Loss: 3.503707 	Validation Loss: 3.920095
# Epoch: 37 	Training Loss: 3.504876 	Validation Loss: 3.969063
# Epoch: 38 	Training Loss: 3.502424 	Validation Loss: 3.917163
# Epoch: 39 	Training Loss: 3.450191 	Validation Loss: 3.890560
# Epoch: 40 	Training Loss: 3.465687 	Validation Loss: 4.016580
# Epoch: 41 	Training Loss: 3.431098 	Validation Loss: 3.973607
# Epoch: 42 	Training Loss: 3.423243 	Validation Loss: 3.876776
# Epoch: 43 	Training Loss: 3.424162 	Validation Loss: 3.965291
# Epoch: 44 	Training Loss: 3.366865 	Validation Loss: 3.978117
# Epoch: 45 	Training Loss: 3.360226 	Validation Loss: 3.967146
# Epoch: 46 	Training Loss: 3.363752 	Validation Loss: 3.881607
# Epoch: 47 	Training Loss: 3.327725 	Validation Loss: 4.012805
# Epoch: 48 	Training Loss: 3.344381 	Validation Loss: 3.978684
# Epoch: 49 	Training Loss: 3.317240 	Validation Loss: 4.075593
# Epoch: 50 	Training Loss: 3.314907 	Validation Loss: 3.859143
# Epoch: 51 	Training Loss: 3.299974 	Validation Loss: 3.954318
# Epoch: 52 	Training Loss: 3.263739 	Validation Loss: 3.995803
# Epoch: 53 	Training Loss: 3.258606 	Validation Loss: 3.982973
# Epoch: 54 	Training Loss: 3.244113 	Validation Loss: 4.005796
# Epoch: 55 	Training Loss: 3.253755 	Validation Loss: 4.051284
# Epoch: 56 	Training Loss: 3.219976 	Validation Loss: 3.974413
# Epoch: 57 	Training Loss: 3.213456 	Validation Loss: 3.980308
# Epoch: 58 	Training Loss: 3.200165 	Validation Loss: 4.121884
# Epoch: 59 	Training Loss: 3.205665 	Validation Loss: 4.036069
# Epoch: 60 	Training Loss: 3.207429 	Validation Loss: 3.922657
# Epoch: 61 	Training Loss: 3.179925 	Validation Loss: 3.980232
# Epoch: 62 	Training Loss: 3.166771 	Validation Loss: 3.974313
# Epoch: 63 	Training Loss: 3.146369 	Validation Loss: 4.043999
# Epoch: 64 	Training Loss: 3.151022 	Validation Loss: 3.855258
# Epoch: 65 	Training Loss: 3.139319 	Validation Loss: 4.164762
# Epoch: 66 	Training Loss: 3.161055 	Validation Loss: 4.042507
# Epoch: 67 	Training Loss: 3.147798 	Validation Loss: 3.951032
# Epoch: 68 	Training Loss: 3.115029 	Validation Loss: 4.004660
# Epoch: 69 	Training Loss: 3.106075 	Validation Loss: 4.233521
# Epoch: 70 	Training Loss: 3.094322 	Validation Loss: 4.029042
# Epoch: 71 	Training Loss: 3.082116 	Validation Loss: 3.968615
# Epoch: 72 	Training Loss: 3.086817 	Validation Loss: 4.057690
# Epoch: 73 	Training Loss: 3.053766 	Validation Loss: 4.064373
# Epoch: 74 	Training Loss: 3.052757 	Validation Loss: 3.972000
# Epoch: 75 	Training Loss: 3.049703 	Validation Loss: 3.906147
# Epoch: 76 	Training Loss: 3.032056 	Validation Loss: 4.068641
# Epoch: 77 	Training Loss: 2.995843 	Validation Loss: 4.001810
# Epoch: 78 	Training Loss: 3.005845 	Validation Loss: 4.238769
# Epoch: 79 	Training Loss: 2.998391 	Validation Loss: 4.066045
# Epoch: 80 	Training Loss: 3.022346 	Validation Loss: 4.083497
# Epoch: 81 	Training Loss: 3.003602 	Validation Loss: 4.116148
# Epoch: 82 	Training Loss: 2.980923 	Validation Loss: 4.236947
# Epoch: 83 	Training Loss: 3.005651 	Validation Loss: 4.175962
# Epoch: 84 	Training Loss: 2.948019 	Validation Loss: 4.084220
# Epoch: 85 	Training Loss: 2.974439 	Validation Loss: 4.263704
# Epoch: 86 	Training Loss: 2.954618 	Validation Loss: 4.012907
# Epoch: 87 	Training Loss: 2.968917 	Validation Loss: 4.096036
# Epoch: 88 	Training Loss: 2.946357 	Validation Loss: 4.014833
# Epoch: 89 	Training Loss: 2.935024 	Validation Loss: 4.010399
# Epoch: 90 	Training Loss: 2.935219 	Validation Loss: 4.051849
# Epoch: 91 	Training Loss: 2.923743 	Validation Loss: 4.013881
# Epoch: 92 	Training Loss: 2.937770 	Validation Loss: 4.094895
# Epoch: 93 	Training Loss: 2.907302 	Validation Loss: 4.087780
# Epoch: 94 	Training Loss: 2.929850 	Validation Loss: 4.123097
# Epoch: 95 	Training Loss: 2.901428 	Validation Loss: 4.183158
# Epoch: 96 	Training Loss: 2.873568 	Validation Loss: 4.101024
# Epoch: 97 	Training Loss: 2.865538 	Validation Loss: 4.169509
# Epoch: 98 	Training Loss: 2.872459 	Validation Loss: 4.215574
# Epoch: 99 	Training Loss: 2.879232 	Validation Loss: 4.185423
# Epoch: 100 	Training Loss: 2.871854 	Validation Loss: 4.093439
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images.  Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 10%.

# %%
def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        # move to GPU
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# call test function    
model_scratch.load_state_dict(torch.load('model_scratch.pt'))
test(loaders_scratch, model_scratch, criterion_scratch, use_cuda)
# Out:
# Test Loss: 3.937058
#
#
# Test Accuracy: 11% (94/836)

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).
#
# If you like, **you are welcome to use the same data loaders from the previous step**, when you created a CNN from scratch.

# %%
## TODO: Specify data loaders
loaders_transfer = get_dataloader(64, 256, 224)

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Use transfer learning to create a CNN to classify dog breed.  Use the code cell below, and save your initialized model as the variable `model_transfer`.

# %%
import torchvision.models as models
import torch.nn as nn

## TODO: Specify model architecture 
model_transfer = models.vgg16(pretrained=True)

for param in model_transfer.parameters():
    param.requires_grad = False
for param in model_transfer.classifier.parameters():
    param.requires_grad = True
    
num_ftrs = model_transfer.classifier[6].in_features
model_transfer.classifier[6] = nn.Linear(num_ftrs, 133)

if use_cuda:
    model_transfer = model_transfer.cuda()

# %% [markdown]
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# __Answer:__
#
# I used the VGG16 as the base network for transfer learning.
#
# - VGG16 has two parts; the first part is convolution layers. This part is mainly used to detect patterns. This part can be directly applied to my use case without updating the parameters. So I have the parameters in this part as untrainable. Reason: pre-trained convolution layers is good enough.
# - The second part is fully connected layers which are the classifier part. I change the out features of the last layer to 133 to suit my use case. And set this part as trainable.  Reason: it is good to train the fully connected layer as the last part of the transfer learning.
#
# I think this architecture is suitable for my use case because VGG16 is a successful model in image classifications and it is also the main goal of my project. I could use the pre-trained weights of VGG16 efficiently with the last few layers trainable.

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/master/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/master/optim.html).  Save the chosen loss function as `criterion_transfer`, and the optimizer as `optimizer_transfer` below.

# %%
criterion_transfer = nn.CrossEntropyLoss()
optimizer_transfer = optim.Adam(model_transfer.classifier.parameters(), lr=0.001)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_transfer.pt'`.

# %%
# train the model
n_epochs = 25
model_transfer = train(n_epochs, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt')

# load the model that got the best validation accuracy (uncomment the line below)
model_transfer.load_state_dict(torch.load('model_transfer.pt'))
# Out:
# True
# Epoch: 1 	Training Loss: 2.650985 	Validation Loss: 1.320544
# Epoch: 2 	Training Loss: 1.937408 	Validation Loss: 1.285374
# Epoch: 3 	Training Loss: 1.894625 	Validation Loss: 1.064942
# Epoch: 4 	Training Loss: 1.939108 	Validation Loss: 1.167524
# Epoch: 5 	Training Loss: 1.955792 	Validation Loss: 1.146877
# Epoch: 6 	Training Loss: 1.951217 	Validation Loss: 1.023805
# Epoch: 7 	Training Loss: 1.961350 	Validation Loss: 1.167543
# Epoch: 8 	Training Loss: 1.847283 	Validation Loss: 1.081465
# Epoch: 9 	Training Loss: 1.838876 	Validation Loss: 1.016173
# Epoch: 10 	Training Loss: 1.801653 	Validation Loss: 0.986090
# Epoch: 11 	Training Loss: 1.860149 	Validation Loss: 1.050260
# Epoch: 12 	Training Loss: 1.792236 	Validation Loss: 0.994601
# Epoch: 13 	Training Loss: 1.796579 	Validation Loss: 0.951834
# Epoch: 14 	Training Loss: 1.792526 	Validation Loss: 1.263531
# Epoch: 15 	Training Loss: 1.795416 	Validation Loss: 1.140113
# Epoch: 16 	Training Loss: 1.966595 	Validation Loss: 1.061072
# Epoch: 17 	Training Loss: 1.724878 	Validation Loss: 1.036485
# Epoch: 18 	Training Loss: 1.708471 	Validation Loss: 1.030691
# Epoch: 19 	Training Loss: 1.782594 	Validation Loss: 1.175021
# Epoch: 20 	Training Loss: 1.812014 	Validation Loss: 1.185274
# Epoch: 21 	Training Loss: 1.709456 	Validation Loss: 1.265208
# Epoch: 22 	Training Loss: 1.751788 	Validation Loss: 1.027969
# Epoch: 23 	Training Loss: 1.739422 	Validation Loss: 1.111657
# Epoch: 24 	Training Loss: 1.779876 	Validation Loss: 1.076934
# Epoch: 25 	Training Loss: 1.711732 	Validation Loss: 1.162973
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60%.

# %%
model_transfer.load_state_dict(torch.load('model_transfer.pt'))
loaders_transfer = get_dataloader(16, 256, 224)
test(loaders_transfer, model_transfer, criterion_transfer, use_cuda)
# Out:
# Test Loss: 1.041801
#
#
# Test Accuracy: 72% (604/836)

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan hound`, etc) that is predicted by your model.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

# list of class names by index, i.e. a name can be accessed like class_names[0]
class_names = [item[4:].replace("_", " ") for item in datasets.ImageFolder(root='dog_images/train').classes]
print(class_names)

def predict_breed_transfer(img_path):
    # load the image and return the predicted breed
    image = Image.open(img_path)
    img_tensor = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406],
            std=[0.229, 0.224, 0.225],
        )]
    )(image)
    c, h, w = img_tensor.shape
    img_tensor = img_tensor.view(-1, 3, 224, 224).to(device)
    # print(img_tensor)
    model_transfer.eval()
    output = model_transfer(img_tensor)
    # print(img_path, output.shape)
    return class_names[output.data.max(1, keepdim=True)[1]]
# Out:
# ['Affenpinscher', 'Afghan hound', 'Airedale terrier', 'Akita', 'Alaskan malamute', 'American eskimo dog', 'American foxhound', 'American staffordshire terrier', 'American water spaniel', 'Anatolian shepherd dog', 'Australian cattle dog', 'Australian shepherd', 'Australian terrier', 'Basenji', 'Basset hound', 'Beagle', 'Bearded collie', 'Beauceron', 'Bedlington terrier', 'Belgian malinois', 'Belgian sheepdog', 'Belgian tervuren', 'Bernese mountain dog', 'Bichon frise', 'Black and tan coonhound', 'Black russian terrier', 'Bloodhound', 'Bluetick coonhound', 'Border collie', 'Border terrier', 'Borzoi', 'Boston terrier', 'Bouvier des flandres', 'Boxer', 'Boykin spaniel', 'Briard', 'Brittany', 'Brussels griffon', 'Bull terrier', 'Bulldog', 'Bullmastiff', 'Cairn terrier', 'Canaan dog', 'Cane corso', 'Cardigan welsh corgi', 'Cavalier king charles spaniel', 'Chesapeake bay retriever', 'Chihuahua', 'Chinese crested', 'Chinese shar-pei', 'Chow chow', 'Clumber spaniel', 'Cocker spaniel', 'Collie', 'Curly-coated retriever', 'Dachshund', 'Dalmatian', 'Dandie dinmont terrier', 'Doberman pinscher', 'Dogue de bordeaux', 'English cocker spaniel', 'English setter', 'English springer spaniel', 'English toy spaniel', 'Entlebucher mountain dog', 'Field spaniel', 'Finnish spitz', 'Flat-coated retriever', 'French bulldog', 'German pinscher', 'German shepherd dog', 'German shorthaired pointer', 'German wirehaired pointer', 'Giant schnauzer', 'Glen of imaal terrier', 'Golden retriever', 'Gordon setter', 'Great dane', 'Great pyrenees', 'Greater swiss mountain dog', 'Greyhound', 'Havanese', 'Ibizan hound', 'Icelandic sheepdog', 'Irish red and white setter', 'Irish setter', 'Irish terrier', 'Irish water spaniel', 'Irish wolfhound', 'Italian greyhound', 'Japanese chin', 'Keeshond', 'Kerry blue terrier', 'Komondor', 'Kuvasz', 'Labrador retriever', 'Lakeland terrier', 'Leonberger', 'Lhasa apso', 'Lowchen', 'Maltese', 'Manchester terrier', 'Mastiff', 'Miniature schnauzer', 'Neapolitan mastiff', 'Newfoundland', 'Norfolk terrier', 'Norwegian buhund', 'Norwegian elkhound', 'Norwegian lundehund', 'Norwich terrier', 'Nova scotia duck tolling retriever', 'Old english sheepdog', 'Otterhound', 'Papillon', 'Parson russell terrier', 'Pekingese', 'Pembroke welsh corgi', 'Petit basset griffon vendeen', 'Pharaoh hound', 'Plott', 'Pointer', 'Pomeranian', 'Poodle', 'Portuguese water dog', 'Saint bernard', 'Silky terrier', 'Smooth fox terrier', 'Tibetan mastiff', 'Welsh springer spaniel', 'Wirehaired pointing griffon', 'Xoloitzcuintli', 'Yorkshire terrier']

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `human_detector` functions developed above.  You are __required__ to use your CNN from Step 4 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

def run_app(img_path):
    ## handle cases for a human face, dog, and neither
    if face_detector(img_path):
        breed = predict_breed_transfer(img_path)
        print("You look like a {}".format(breed))
    elif dog_detector(img_path):
        breed = predict_breed_transfer(img_path)
        print("The breed of the dog is {}".format(breed))
    else:
        print("Error, neither human nor dog detected!")

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that _you_ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.

# %% [markdown]
# __Answer:__ (Three possible points for improvement)
#
# It is about what I expected.
#
# **Possible improvements**
#
# - The dog detector directly uses VGG16, I can use transfer learning to make it a binary classifer. The accuracy might be better.
#
# - The human detector used opencv. It might be better to use a well-trained neural network.
#
# - The training data for dog breed might not be enough. It would be useful to gather more training data to improve the result.

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

## suggested code, below
for file in np.hstack((human_files[:10], dog_files[:10])):
    run_app(file)
# Out:
# You look like a Chesapeake bay retriever
# You look like a Norfolk terrier
# Error, neither human nor dog detected!
# You look like a Afghan hound
# You look like a Dachshund
# You look like a Golden retriever
# You look like a Xoloitzcuintli
# You look like a Afghan hound
# You look like a Dachshund
# You look like a Doberman pinscher
# The breed of the dog is Affenpinscher
# The breed of the dog is Affenpinscher
# The breed of the dog is Brussels griffon
# The breed of the dog is Affenpinscher
# The breed of the dog is Affenpinscher
# The breed of the dog is Lhasa apso
# Error, neither human nor dog detected!
# The breed of the dog is Affenpinscher
# The breed of the dog is Afghan hound
# The breed of the dog is Afghan hound

# %%
for i in dog_files[: 200]:
    print (i, predict_breed_transfer(i))
# Out:
# dog_images\test\001.Affenpinscher\Affenpinscher_00003.jpg Affenpinscher
# dog_images\test\001.Affenpinscher\Affenpinscher_00023.jpg Affenpinscher
# dog_images\test\001.Affenpinscher\Affenpinscher_00036.jpg Brussels griffon
# dog_images\test\001.Affenpinscher\Affenpinscher_00047.jpg Affenpinscher
# dog_images\test\001.Affenpinscher\Affenpinscher_00048.jpg Affenpinscher
# dog_images\test\001.Affenpinscher\Affenpinscher_00058.jpg Lhasa apso
# dog_images\test\001.Affenpinscher\Affenpinscher_00071.jpg Affenpinscher
# dog_images\test\001.Affenpinscher\Affenpinscher_00078.jpg Affenpinscher
# dog_images\test\002.Afghan_hound\Afghan_hound_00116.jpg Afghan hound
# dog_images\test\002.Afghan_hound\Afghan_hound_00125.jpg Afghan hound
# dog_images\test\002.Afghan_hound\Afghan_hound_00139.jpg Afghan hound
# dog_images\test\002.Afghan_hound\Afghan_hound_00141.jpg Afghan hound
# dog_images\test\002.Afghan_hound\Afghan_hound_00143.jpg Afghan hound
# dog_images\test\002.Afghan_hound\Afghan_hound_00146.jpg English setter
# dog_images\test\002.Afghan_hound\Afghan_hound_00149.jpg Afghan hound
# dog_images\test\002.Afghan_hound\Afghan_hound_00151.jpg Afghan hound
# dog_images\test\003.Airedale_terrier\Airedale_terrier_00166.jpg Airedale terrier
# dog_images\test\003.Airedale_terrier\Airedale_terrier_00175.jpg Airedale terrier
# dog_images\test\003.Airedale_terrier\Airedale_terrier_00179.jpg Airedale terrier
# dog_images\test\003.Airedale_terrier\Airedale_terrier_00207.jpg Airedale terrier
# dog_images\test\003.Airedale_terrier\Airedale_terrier_00210.jpg Irish terrier
# dog_images\test\003.Airedale_terrier\Airedale_terrier_00214.jpg Airedale terrier
# dog_images\test\004.Akita\Akita_00244.jpg Akita
# dog_images\test\004.Akita\Akita_00258.jpg Canaan dog
# dog_images\test\004.Akita\Akita_00262.jpg Canaan dog
# dog_images\test\004.Akita\Akita_00263.jpg Akita
# dog_images\test\004.Akita\Akita_00270.jpg Norwegian elkhound
# dog_images\test\004.Akita\Akita_00276.jpg Finnish spitz
# dog_images\test\004.Akita\Akita_00282.jpg Akita
# dog_images\test\004.Akita\Akita_00296.jpg Akita
# dog_images\test\005.Alaskan_malamute\Alaskan_malamute_00309.jpg Alaskan malamute
# dog_images\test\005.Alaskan_malamute\Alaskan_malamute_00330.jpg Alaskan malamute
# dog_images\test\005.Alaskan_malamute\Alaskan_malamute_00346.jpg Alaskan malamute
# dog_images\test\005.Alaskan_malamute\Alaskan_malamute_00354.jpg Alaskan malamute
# dog_images\test\005.Alaskan_malamute\Alaskan_malamute_00360.jpg Alaskan malamute
# dog_images\test\005.Alaskan_malamute\Alaskan_malamute_00362.jpg Alaskan malamute
# dog_images\test\005.Alaskan_malamute\Alaskan_malamute_00375.jpg Alaskan malamute
# dog_images\test\005.Alaskan_malamute\Alaskan_malamute_00383.jpg Alaskan malamute
# dog_images\test\005.Alaskan_malamute\Alaskan_malamute_00386.jpg Alaskan malamute
# dog_images\test\005.Alaskan_malamute\Alaskan_malamute_00387.jpg Alaskan malamute
# dog_images\test\006.American_eskimo_dog\American_eskimo_dog_00406.jpg American eskimo dog
# dog_images\test\006.American_eskimo_dog\American_eskimo_dog_00407.jpg American eskimo dog
# dog_images\test\006.American_eskimo_dog\American_eskimo_dog_00415.jpg Icelandic sheepdog
# dog_images\test\006.American_eskimo_dog\American_eskimo_dog_00451.jpg Icelandic sheepdog
# dog_images\test\006.American_eskimo_dog\American_eskimo_dog_00452.jpg American eskimo dog
# dog_images\test\006.American_eskimo_dog\American_eskimo_dog_00454.jpg American eskimo dog
# dog_images\test\006.American_eskimo_dog\American_eskimo_dog_00467.jpg American eskimo dog
# dog_images\test\006.American_eskimo_dog\American_eskimo_dog_00471.jpg Pomeranian
# dog_images\test\007.American_foxhound\American_foxhound_00484.jpg Dachshund
# dog_images\test\007.American_foxhound\American_foxhound_00512.jpg American foxhound
# dog_images\test\007.American_foxhound\American_foxhound_00519.jpg American foxhound
# dog_images\test\007.American_foxhound\American_foxhound_00522.jpg American foxhound
# dog_images\test\007.American_foxhound\American_foxhound_00524.jpg Beagle
# dog_images\test\007.American_foxhound\American_foxhound_00531.jpg American foxhound
# dog_images\test\007.American_foxhound\American_foxhound_00535.jpg American foxhound
# dog_images\test\008.American_staffordshire_terrier\American_staffordshire_terrier_00538.jpg American staffordshire terrier
# dog_images\test\008.American_staffordshire_terrier\American_staffordshire_terrier_00539.jpg American staffordshire terrier
# dog_images\test\008.American_staffordshire_terrier\American_staffordshire_terrier_00540.jpg American staffordshire terrier
# dog_images\test\008.American_staffordshire_terrier\American_staffordshire_terrier_00556.jpg Boxer
# dog_images\test\008.American_staffordshire_terrier\American_staffordshire_terrier_00567.jpg American staffordshire terrier
# dog_images\test\008.American_staffordshire_terrier\American_staffordshire_terrier_00579.jpg German pinscher
# dog_images\test\008.American_staffordshire_terrier\American_staffordshire_terrier_00580.jpg American staffordshire terrier
# dog_images\test\008.American_staffordshire_terrier\American_staffordshire_terrier_00607.jpg Bulldog
# dog_images\test\009.American_water_spaniel\American_water_spaniel_00624.jpg American water spaniel
# dog_images\test\009.American_water_spaniel\American_water_spaniel_00631.jpg English springer spaniel
# dog_images\test\009.American_water_spaniel\American_water_spaniel_00646.jpg German wirehaired pointer
# dog_images\test\009.American_water_spaniel\American_water_spaniel_00655.jpg Boykin spaniel
# dog_images\test\010.Anatolian_shepherd_dog\Anatolian_shepherd_dog_00661.jpg Anatolian shepherd dog
# dog_images\test\010.Anatolian_shepherd_dog\Anatolian_shepherd_dog_00669.jpg Anatolian shepherd dog
# dog_images\test\010.Anatolian_shepherd_dog\Anatolian_shepherd_dog_00673.jpg Anatolian shepherd dog
# dog_images\test\010.Anatolian_shepherd_dog\Anatolian_shepherd_dog_00690.jpg Anatolian shepherd dog
# dog_images\test\010.Anatolian_shepherd_dog\Anatolian_shepherd_dog_00695.jpg Anatolian shepherd dog
# dog_images\test\010.Anatolian_shepherd_dog\Anatolian_shepherd_dog_00710.jpg Anatolian shepherd dog
# dog_images\test\011.Australian_cattle_dog\Australian_cattle_dog_00727.jpg Australian cattle dog
# dog_images\test\011.Australian_cattle_dog\Australian_cattle_dog_00728.jpg Pembroke welsh corgi
# dog_images\test\011.Australian_cattle_dog\Australian_cattle_dog_00730.jpg Australian cattle dog
# dog_images\test\011.Australian_cattle_dog\Australian_cattle_dog_00734.jpg Australian cattle dog
# dog_images\test\011.Australian_cattle_dog\Australian_cattle_dog_00761.jpg Norwegian buhund
# dog_images\test\011.Australian_cattle_dog\Australian_cattle_dog_00781.jpg German shepherd dog
# dog_images\test\011.Australian_cattle_dog\Australian_cattle_dog_00788.jpg Australian cattle dog
# dog_images\test\011.Australian_cattle_dog\Australian_cattle_dog_00792.jpg Akita
# dog_images\test\011.Australian_cattle_dog\Australian_cattle_dog_00803.jpg Australian cattle dog
# dog_images\test\012.Australian_shepherd\Australian_shepherd_00830.jpg Cavalier king charles spaniel
# dog_images\test\012.Australian_shepherd\Australian_shepherd_00836.jpg Australian shepherd
# dog_images\test\012.Australian_shepherd\Australian_shepherd_00843.jpg Brittany
# dog_images\test\012.Australian_shepherd\Australian_shepherd_00848.jpg Entlebucher mountain dog
# dog_images\test\012.Australian_shepherd\Australian_shepherd_00853.jpg Australian shepherd
# dog_images\test\012.Australian_shepherd\Australian_shepherd_00864.jpg Border collie
# dog_images\test\012.Australian_shepherd\Australian_shepherd_00868.jpg Nova scotia duck tolling retriever
# dog_images\test\012.Australian_shepherd\Australian_shepherd_00870.jpg Australian shepherd
# dog_images\test\012.Australian_shepherd\Australian_shepherd_00887.jpg Australian shepherd
# dog_images\test\013.Australian_terrier\Australian_terrier_00897.jpg Australian terrier
# dog_images\test\013.Australian_terrier\Australian_terrier_00900.jpg Silky terrier
# dog_images\test\013.Australian_terrier\Australian_terrier_00918.jpg Irish terrier
# dog_images\test\013.Australian_terrier\Australian_terrier_00923.jpg Silky terrier
# dog_images\test\013.Australian_terrier\Australian_terrier_00925.jpg Australian terrier
# dog_images\test\013.Australian_terrier\Australian_terrier_00930.jpg Australian terrier
# dog_images\test\014.Basenji\Basenji_00955.jpg Basenji
# dog_images\test\014.Basenji\Basenji_00959.jpg Basenji
# dog_images\test\014.Basenji\Basenji_00961.jpg Pembroke welsh corgi
# dog_images\test\014.Basenji\Basenji_00974.jpg Basenji
# dog_images\test\014.Basenji\Basenji_00978.jpg Basenji
# dog_images\test\014.Basenji\Basenji_00985.jpg Basenji
# dog_images\test\014.Basenji\Basenji_00987.jpg Basenji
# dog_images\test\014.Basenji\Basenji_01009.jpg Basenji
# dog_images\test\014.Basenji\Basenji_01029.jpg Basenji
# dog_images\test\015.Basset_hound\Basset_hound_01034.jpg Basset hound
# dog_images\test\015.Basset_hound\Basset_hound_01044.jpg Basset hound
# dog_images\test\015.Basset_hound\Basset_hound_01059.jpg Basset hound
# dog_images\test\015.Basset_hound\Basset_hound_01067.jpg Bluetick coonhound
# dog_images\test\015.Basset_hound\Basset_hound_01071.jpg Basset hound
# dog_images\test\015.Basset_hound\Basset_hound_01080.jpg Dachshund
# dog_images\test\015.Basset_hound\Basset_hound_01085.jpg Basset hound
# dog_images\test\015.Basset_hound\Basset_hound_01097.jpg Beagle
# dog_images\test\015.Basset_hound\Basset_hound_01106.jpg Basset hound
# dog_images\test\015.Basset_hound\Basset_hound_01121.jpg Basset hound
# dog_images\test\016.Beagle\Beagle_01130.jpg Beagle
# dog_images\test\016.Beagle\Beagle_01141.jpg Beagle
# dog_images\test\016.Beagle\Beagle_01144.jpg Beagle
# dog_images\test\016.Beagle\Beagle_01150.jpg Beagle
# dog_images\test\016.Beagle\Beagle_01155.jpg Beagle
# dog_images\test\016.Beagle\Beagle_01156.jpg Beagle
# dog_images\test\016.Beagle\Beagle_01196.jpg Beagle
# dog_images\test\016.Beagle\Beagle_01197.jpg Beagle
# dog_images\test\017.Bearded_collie\Bearded_collie_01205.jpg Bearded collie
# dog_images\test\017.Bearded_collie\Bearded_collie_01215.jpg Bearded collie
# dog_images\test\017.Bearded_collie\Bearded_collie_01221.jpg Bearded collie
# dog_images\test\017.Bearded_collie\Bearded_collie_01227.jpg Bearded collie
# dog_images\test\017.Bearded_collie\Bearded_collie_01231.jpg Bearded collie
# dog_images\test\017.Bearded_collie\Bearded_collie_01233.jpg Havanese
# dog_images\test\017.Bearded_collie\Bearded_collie_01253.jpg Bearded collie
# dog_images\test\017.Bearded_collie\Bearded_collie_01274.jpg Bearded collie
# dog_images\test\018.Beauceron\Beauceron_01284.jpg Doberman pinscher
# dog_images\test\018.Beauceron\Beauceron_01292.jpg Beauceron
# dog_images\test\018.Beauceron\Beauceron_01299.jpg Beauceron
# dog_images\test\018.Beauceron\Beauceron_01303.jpg Beauceron
# dog_images\test\018.Beauceron\Beauceron_01310.jpg Beauceron
# dog_images\test\018.Beauceron\Beauceron_01319.jpg Doberman pinscher
# dog_images\test\018.Beauceron\Beauceron_01328.jpg Beauceron
# dog_images\test\019.Bedlington_terrier\Bedlington_terrier_01340.jpg Bedlington terrier
# dog_images\test\019.Bedlington_terrier\Bedlington_terrier_01363.jpg Bedlington terrier
# dog_images\test\019.Bedlington_terrier\Bedlington_terrier_01368.jpg Bedlington terrier
# dog_images\test\019.Bedlington_terrier\Bedlington_terrier_01369.jpg Bedlington terrier
# dog_images\test\019.Bedlington_terrier\Bedlington_terrier_01381.jpg Bedlington terrier
# dog_images\test\019.Bedlington_terrier\Bedlington_terrier_01392.jpg Bedlington terrier
# dog_images\test\020.Belgian_malinois\Belgian_malinois_01407.jpg Belgian malinois
# dog_images\test\020.Belgian_malinois\Belgian_malinois_01441.jpg Belgian malinois
# dog_images\test\020.Belgian_malinois\Belgian_malinois_01445.jpg Belgian malinois
# dog_images\test\020.Belgian_malinois\Belgian_malinois_01452.jpg Belgian malinois
# dog_images\test\020.Belgian_malinois\Belgian_malinois_01460.jpg Belgian malinois
# dog_images\test\020.Belgian_malinois\Belgian_malinois_01469.jpg Belgian malinois
# dog_images\test\020.Belgian_malinois\Belgian_malinois_01471.jpg Belgian malinois
# dog_images\test\020.Belgian_malinois\Belgian_malinois_01472.jpg Belgian malinois
# dog_images\test\021.Belgian_sheepdog\Belgian_sheepdog_01482.jpg Belgian sheepdog
# dog_images\test\021.Belgian_sheepdog\Belgian_sheepdog_01486.jpg Belgian sheepdog
# dog_images\test\021.Belgian_sheepdog\Belgian_sheepdog_01488.jpg Belgian sheepdog
# dog_images\test\021.Belgian_sheepdog\Belgian_sheepdog_01491.jpg Belgian sheepdog
# dog_images\test\021.Belgian_sheepdog\Belgian_sheepdog_01540.jpg Belgian sheepdog
# dog_images\test\021.Belgian_sheepdog\Belgian_sheepdog_01548.jpg Giant schnauzer
# dog_images\test\021.Belgian_sheepdog\Belgian_sheepdog_01554.jpg Belgian sheepdog
# dog_images\test\021.Belgian_sheepdog\Belgian_sheepdog_01555.jpg Belgian sheepdog
# dog_images\test\022.Belgian_tervuren\Belgian_tervuren_01561.jpg Belgian tervuren
# dog_images\test\022.Belgian_tervuren\Belgian_tervuren_01574.jpg Belgian tervuren
# dog_images\test\022.Belgian_tervuren\Belgian_tervuren_01585.jpg Belgian tervuren
# dog_images\test\022.Belgian_tervuren\Belgian_tervuren_01588.jpg Belgian tervuren
# dog_images\test\022.Belgian_tervuren\Belgian_tervuren_01601.jpg Belgian tervuren
# dog_images\test\022.Belgian_tervuren\Belgian_tervuren_01607.jpg Belgian tervuren
# dog_images\test\023.Bernese_mountain_dog\Bernese_mountain_dog_01617.jpg Bernese mountain dog
# dog_images\test\023.Bernese_mountain_dog\Bernese_mountain_dog_01622.jpg Bernese mountain dog
# dog_images\test\023.Bernese_mountain_dog\Bernese_mountain_dog_01632.jpg Bernese mountain dog
# dog_images\test\023.Bernese_mountain_dog\Bernese_mountain_dog_01638.jpg Bernese mountain dog
# dog_images\test\023.Bernese_mountain_dog\Bernese_mountain_dog_01646.jpg Bernese mountain dog
# dog_images\test\023.Bernese_mountain_dog\Bernese_mountain_dog_01653.jpg Bernese mountain dog
# dog_images\test\023.Bernese_mountain_dog\Bernese_mountain_dog_01657.jpg Bernese mountain dog
# dog_images\test\023.Bernese_mountain_dog\Bernese_mountain_dog_01682.jpg Bernese mountain dog
# dog_images\test\024.Bichon_frise\Bichon_frise_01707.jpg Bichon frise
# dog_images\test\024.Bichon_frise\Bichon_frise_01719.jpg Bichon frise
# dog_images\test\024.Bichon_frise\Bichon_frise_01726.jpg Bichon frise
# dog_images\test\024.Bichon_frise\Bichon_frise_01753.jpg Bichon frise
# dog_images\test\024.Bichon_frise\Bichon_frise_01757.jpg Havanese
# dog_images\test\024.Bichon_frise\Bichon_frise_01759.jpg Bichon frise
# dog_images\test\024.Bichon_frise\Bichon_frise_01760.jpg Old english sheepdog
# dog_images\test\024.Bichon_frise\Bichon_frise_01767.jpg Bichon frise
# dog_images\test\025.Black_and_tan_coonhound\Black_and_tan_coonhound_01789.jpg Black and tan coonhound
# dog_images\test\025.Black_and_tan_coonhound\Black_and_tan_coonhound_01795.jpg Black and tan coonhound
# dog_images\test\025.Black_and_tan_coonhound\Black_and_tan_coonhound_01801.jpg Dachshund
# dog_images\test\025.Black_and_tan_coonhound\Black_and_tan_coonhound_01803.jpg Black and tan coonhound
# dog_images\test\026.Black_russian_terrier\Black_russian_terrier_01827.jpg Black russian terrier
# dog_images\test\026.Black_russian_terrier\Black_russian_terrier_01837.jpg Kerry blue terrier
# dog_images\test\026.Black_russian_terrier\Black_russian_terrier_01840.jpg Bouvier des flandres
# dog_images\test\026.Black_russian_terrier\Black_russian_terrier_01849.jpg Bouvier des flandres
# dog_images\test\026.Black_russian_terrier\Black_russian_terrier_01868.jpg Black russian terrier
# dog_images\test\027.Bloodhound\Bloodhound_01871.jpg Bloodhound
# dog_images\test\027.Bloodhound\Bloodhound_01885.jpg Bloodhound
# dog_images\test\027.Bloodhound\Bloodhound_01900.jpg Mastiff
# dog_images\test\027.Bloodhound\Bloodhound_01906.jpg Bloodhound
# dog_images\test\027.Bloodhound\Bloodhound_01912.jpg Bloodhound
# dog_images\test\027.Bloodhound\Bloodhound_01921.jpg Bloodhound
# dog_images\test\027.Bloodhound\Bloodhound_01923.jpg Bloodhound
# dog_images\test\027.Bloodhound\Bloodhound_01934.jpg Bloodhound

# %%
files1 = 'dog_Images/test/130.Welsh_springer_spaniel/Welsh_springer_spaniel_08214.jpg'
print (predict_breed_transfer(files1))
im1 = Image.open(files1)
im1.resize((300, 200))
# Out:
# Welsh springer spaniel
# <PIL.Image.Image image mode=RGB size=300x200 at 0x1C8670D15C0>

# %%
files2 = 'dog_Images/test/037.Brittany/Brittany_02591.jpg'
print (predict_breed_transfer(files2))
im2 = Image.open(files2)
im2.resize((300, 200))
# Out:
# Brittany
# <PIL.Image.Image image mode=RGB size=300x200 at 0x1C863163E48>
